# %% [markdown]
# ### 1D plot using matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Sine Wave')
plt.savefig("../../images/img01/plot-sine-wave.png")
plt.show()

# %% [markdown]
# ### 2D contour plot

# %%
x = np.linspace(-10, 10, 200)
y = np.linspace(-10, 10, 200)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.exp(-0.1*(X**2 + Y**2)) * np.cos(5*R)
plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar(label='Field value')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Gaussian-Modulated Cosine')
plt.savefig("../../images/img01/plot-gaussian-modulated-cosine-field.png")
plt.show()

# %% [markdown]
# ### 3D surface plot

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
ax.plot_surface(X, Y, Z, cmap='viridis')
plt.title('3D Surface Plot')
plt.savefig("../../images/img01/plot-3d-surface.png")
plt.show()
